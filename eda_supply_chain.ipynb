# %%
import pandas as pd

df = pd.read_csv(r"C:\\Users\\acer\\OneDrive\\Documents\\Supply-Chain-Inventory-Analytics\\Data\\DataCoSupplyChainDataset.csv", encoding="latin1")

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (180519, 53)
# ...

# %%
print(df.isnull().sum())
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
print("Duplicates:", df.duplicated().sum())
# Out:
# Duplicates: 0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  str
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  str
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  str
#  9   Customer City                  180519 non-null  str
#  10  Customer Country               180519 non-null  str
#  11  Customer Email                 180519 non-null  str
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %%
df.describe( include ='object')
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_16184\3240871432.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe( include ='object')
#           Type Delivery Status Category Name Customer City Customer Country  \
# count   180519          180519        180519        180519           180519
# unique       4               4            50           563                2
# top      DEBIT   Late delivery        Cleats        Caguas          EE. UU.
# freq     69295           98977         24551         66770           111146
#
# ...

# %%
for col in df.columns:
    if df[col].nunique() == 1:
        print(col)
# Out:
# Customer Email
# Customer Password
# Product Status

# %%
df[['Benefit per order',
    'Order Profit Per Order',
    'Sales',
    'Product Price',
    'Order Item Quantity']].describe()
# Out:
#        Benefit per order  Order Profit Per Order          Sales  \
# count      180519.000000           180519.000000  180519.000000
# mean           21.974989               21.974989     203.772096
# std           104.433526              104.433526     132.273077
# min         -4274.979980            -4274.979980       9.990000
# 25%             7.000000                7.000000     119.980003
# 50%            31.520000               31.520000     199.919998
# 75%            64.800003               64.800003     299.950012
# max           911.799988              911.799988    1999.989990
#
#        Product Price  Order Item Quantity
# count  180519.000000        180519.000000
# mean      141.232550             2.127638
# std       139.732492             1.453451
# min         9.990000             1.000000
# 25%        50.000000             1.000000
# 50%        59.990002             1.000000
# 75%       199.990005             3.000000
# max      1999.989990             5.000000

# %%
cols_to_drop = [
    'Customer Email',
    'Customer Password',
    'Product Status',
    'Product Image'
]

df = df.drop(columns=cols_to_drop)

# %%
print(df.shape)
# Out:
# (180519, 49)

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Customer Lname              8
# Customer Zipcode            3
# Order Zipcode          155679
# Product Description    180519
# dtype: int64

# %%
df['Customer Lname'] = df['Customer Lname'].fillna('Unknown')

df['Customer Zipcode'] = df['Customer Zipcode'].fillna(
    df['Customer Zipcode'].mode()[0]
)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(336198)

# %%
print(df.columns.tolist())
# Out:
# ['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)', 'Benefit per order', 'Sales per customer', 'Delivery Status', 'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City', 'Customer Country', 'Customer Fname', 'Customer Id', 'Customer Lname', 'Customer Segment', 'Customer State', 'Customer Street', 'Customer Zipcode', 'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market', 'Order City', 'Order Country', 'Order Customer Id', 'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id', 'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price', 'Order Item Profit Ratio', 'Order Item Quantity', 'Sales', 'Order Item Total', 'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status', 'Order Zipcode', 'Product Card Id', 'Product Category Id', 'Product Description', 'Product Name', 'Product Price', 'shipping date (DateOrders)', 'Shipping Mode']

# %%
df = df.drop(columns=['Order Zipcode'])

# %%
df['Customer Lname'] = df['Customer Lname'].fillna('Unknown')

df['Customer Zipcode'] = df['Customer Zipcode'].fillna(
    df['Customer Zipcode'].mode()[0]
)

# %%
df = df.drop(columns=['Product Description'])

# %%
print(df.isnull().sum().sum())
print(df.shape)
# Out:
# 0
# (180519, 47)

# %%
df['order date (DateOrders)'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
 df['shipping date (DateOrders)'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['order_date_raw'] = df['order date (DateOrders)']

# %%
df['shipping_date_raw'] = df['shipping date (DateOrders)']

# %%
df['order date (DateOrders)'] = pd.to_datetime(
    df['order_date_raw'],
    errors='coerce'
)

# %%
df['order date (DateOrders)'].isna().sum()
# Out:
# np.int64(71103)

# %%
df[df['order_date_raw'].str.contains('-', na=False)][
    'order_date_raw'
].head(5)
# Out:
# 37    01-12-2018 23:51
# 38    01-12-2018 23:30
# 39    01-12-2018 23:09
# 40    01-12-2018 22:48
# 41    01-12-2018 22:27
# Name: order_date_raw, dtype: str

# %%
pd.to_datetime('01-12-2018 23:51')
# Out:
# Timestamp('2018-01-12 23:51:00')

# %%
pd.to_datetime('1/13/2018 12:27')
# Out:
# Timestamp('2018-01-13 12:27:00')

# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.1'

# %%
order_test = pd.to_datetime(
    df['order_date_raw'],
    format='mixed',
    errors='coerce'
)

order_test.isna().sum()
# Out:
# np.int64(0)

# %%
df['order date (DateOrders)'].isna().sum()
# Out:
# np.int64(71103)

# %%
df['order date (DateOrders)'].head()
# Out:
# 0   2018-01-31 22:56:00
# 1   2018-01-13 12:27:00
# 2   2018-01-13 12:06:00
# 3   2018-01-13 11:45:00
# 4   2018-01-13 11:24:00
# Name: order date (DateOrders), dtype: datetime64[us]

# %%
df['order date (DateOrders)'].isna().sum()
# Out:
# np.int64(71103)

# %%
df.loc[37:41, ['order_date_raw', 'order date (DateOrders)']]
# Out:
#       order_date_raw order date (DateOrders)
# 37  01-12-2018 23:51                     NaT
# 38  01-12-2018 23:30                     NaT
# 39  01-12-2018 23:09                     NaT
# 40  01-12-2018 22:48                     NaT
# 41  01-12-2018 22:27                     NaT

# %%
order_test = pd.to_datetime(
    df['order_date_raw'],
    format='mixed',
    errors='coerce'
)

# %%
df['order date (DateOrders)'] = order_test

# %%
df['order date (DateOrders)'].isna().sum()
# Out:
# np.int64(0)

# %%
shipping_test = pd.to_datetime(
    df['shipping_date_raw'],
    format='mixed',
    errors='coerce'
)

# %%
shipping_test.isna().sum()
# Out:
# np.int64(0)

# %%
df['shipping date (DateOrders)'] = shipping_test

# %%
df['shipping date (DateOrders)'].isna().sum()
# Out:
# np.int64(0)

# %%
df[['order date (DateOrders)', 'shipping date (DateOrders)']].dtypes
# Out:
# order date (DateOrders)       datetime64[us]
# shipping date (DateOrders)    datetime64[us]
# dtype: object

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
# std                    1.623722                       1.374449
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# 50%            31.520000          163.990005            1.000000
# ...

# %%
(df['Order Profit Per Order'] < 0).sum()
# Out:
# np.int64(33784)

# %%
(df['Order Profit Per Order'] < 0).mean() * 100
# Out:
# np.float64(18.714927514555253)

# %%
df['Order Status'].value_counts().head(10)
# Out:
# Order Status
# COMPLETE           59491
# PENDING_PAYMENT    39832
# PROCESSING         21902
# PENDING            20227
# CLOSED             19616
# ON_HOLD             9804
# SUSPECTED_FRAUD     4062
# CANCELED            3692
# PAYMENT_REVIEW      1893
# Name: count, dtype: int64

# %%
df['Delivery Status'].value_counts()
# Out:
# Delivery Status
# Late delivery        98977
# Advance shipping     41592
# Shipping on time     32196
# Shipping canceled     7754
# Name: count, dtype: int64

# %%
(df['Delivery Status'] == 'Late delivery').mean() * 100
# Out:
# np.float64(54.82913155955883)

# %%
df['Category Name'].value_counts().head(10)
# Out:
# Category Name
# Cleats                  24551
# Men's Footwear          22246
# Women's Apparel         21035
# Indoor/Outdoor Games    19298
# Fishing                 17325
# Water Sports            15540
# Camping & Hiking        13729
# Cardio Equipment        12487
# Shop By Sport           10984
# Electronics              3156
# Name: count, dtype: int64

# %%
df['Market'].value_counts()
# Out:
# Market
# LATAM           51594
# Europe          50252
# Pacific Asia    41260
# USCA            25799
# Africa          11614
# Name: count, dtype: int64

# %%
df['Customer Segment'].value_counts()
# Out:
# Customer Segment
# Consumer       93504
# Corporate      54789
# Home Office    32226
# Name: count, dtype: int64

# %%
df['Shipping Mode'].value_counts()
# Out:
# Shipping Mode
# Standard Class    107752
# Second Class       35216
# First Class        27814
# Same Day            9737
# Name: count, dtype: int64

# %%
df['Late_delivery_risk'].value_counts()
# Out:
# Late_delivery_risk
# 1    98977
# 0    81542
# Name: count, dtype: int64

# %%
df['Order Country'].value_counts().head(10)
# Out:
# Order Country
# Estados Unidos    24840
# Francia           13222
# México            13172
# Alemania           9564
# Australia          8497
# Brasil             7987
# Reino Unido        7302
# China              5758
# Italia             4989
# India              4783
# Name: count, dtype: int64

# %%
df.groupby('Category Name')['Order Profit Per Order'] \
  .sum() \
  .sort_values(ascending=False) \
  .head(10)
# Out:
# Category Name
# Fishing                 756220.767190
# Cleats                  494636.919791
# Camping & Hiking        427455.568106
# Cardio Equipment        383011.098485
# Women's Apparel         350421.029567
# Water Sports            325146.960038
# Indoor/Outdoor Games    318451.430554
# Men's Footwear          311902.820214
# Shop By Sport           129813.960315
# Computers                69656.810171
# Name: Order Profit Per Order, dtype: float64

# %%
df.groupby('Category Name')['Order Profit Per Order'] \
  .sum() \
  .sort_values() \
  .head(10)
# Out:
# Category Name
# Strength Training     332.310091
# CDs                   383.850000
# As Seen on  TV!       714.429980
# Books                 883.010008
# Toys                  900.710000
# Baby                 1525.029992
# Golf Bags & Carts    1810.069992
# Basketball           1845.670003
# Men's Clothing       2006.039969
# Video Games          2717.519997
# Name: Order Profit Per Order, dtype: float64

# %%
df.groupby('Market')['Order Profit Per Order'] \
  .sum() \
  .sort_values(ascending=False)
# Out:
# Market
# Europe          1.169443e+06
# LATAM           1.123322e+06
# Pacific Asia    8.577534e+05
# USCA            5.643138e+05
# Africa          2.520712e+05
# Name: Order Profit Per Order, dtype: float64

# %%
df.groupby('Customer Segment')['Order Profit Per Order'] \
  .sum() \
  .sort_values(ascending=False)
# Out:
# Customer Segment
# Consumer       2.073488e+06
# Corporate      1.202575e+06
# Home Office    6.908403e+05
# Name: Order Profit Per Order, dtype: float64

# %%
df['order date (DateOrders)'].dt.year.value_counts().sort_index()
# Out:
# order date (DateOrders)
# 2015    62650
# 2016    62550
# 2017    53196
# 2018     2123
# Name: count, dtype: int64

# %%
df['order date (DateOrders)'].dt.month.value_counts().sort_index()
# Out:
# order date (DateOrders)
# 1     17979
# 2     14529
# 3     15919
# 4     15435
# 5     15976
# 6     15139
# 7     15922
# 8     15912
# 9     15489
# 10    12955
# 11    12500
# 12    12764
# Name: count, dtype: int64

# %%
df.groupby(
    df['order date (DateOrders)'].dt.month
)['Sales'].sum().sort_index()
# Out:
# order date (DateOrders)
# 1     3.459246e+06
# 2     2.888088e+06
# 3     3.125112e+06
# 4     3.053996e+06
# 5     3.185364e+06
# 6     3.059152e+06
# 7     3.188170e+06
# 8     3.187032e+06
# 9     3.164511e+06
# 10    3.171279e+06
# 11    2.703625e+06
# 12    2.599160e+06
# Name: Sales, dtype: float64

# %%
df.groupby('Shipping Mode')['Sales'] \
  .sum() \
  .sort_values(ascending=False)
# Out:
# Shipping Mode
# Standard Class    2.202239e+07
# Second Class      7.145445e+06
# First Class       5.674370e+06
# Same Day          1.942529e+06
# Name: Sales, dtype: float64

# %%
df.groupby('Delivery Status')['Order Profit Per Order'] \
  .mean() \
  .sort_values()
# Out:
# Delivery Status
# Shipping canceled    20.696717
# Late delivery        21.621707
# Advance shipping     22.485701
# Shipping on time     22.709146
# Name: Order Profit Per Order, dtype: float64

# %%
pd.crosstab(
    df['Market'],
    df['Delivery Status'],
    normalize='index'
) * 100
# Out:
# Delivery Status  Advance shipping  Late delivery  Shipping canceled  \
# Market
# Africa                  22.774238      54.589289           3.960737
# Europe                  23.091618      55.207753           4.302316
# LATAM                   23.334109      54.355158           4.428810
# Pacific Asia            22.959283      55.046049           4.059622
# USCA                    22.601651      54.800574           4.542812
#
# Delivery Status  Shipping on time
# Market
# Africa                  18.675736
# Europe                  17.398313
# LATAM                   17.881924
# Pacific Asia            17.935046
# USCA                    18.054963

# %%
pd.crosstab(
    df['Shipping Mode'],
    df['Delivery Status'],
    normalize='index'
) * 100
# Out:
# Delivery Status  Advance shipping  Late delivery  Shipping canceled  \
# Shipping Mode
# First Class              0.000000      95.322499           4.677501
# Same Day                 0.000000      45.743042           4.559926
# Second Class             0.000000      76.632781           4.003862
# Standard Class          38.599748      38.071683           4.268134
#
# Delivery Status  Shipping on time
# Shipping Mode
# First Class              0.000000
# Same Day                49.697032
# Second Class            19.363358
# Standard Class          19.060435

# %%
df.groupby('Shipping Mode')['Order Profit Per Order'] \
  .mean() \
  .sort_values(ascending=False)
# Out:
# Shipping Mode
# First Class       23.122238
# Standard Class    21.999169
# Second Class      21.305889
# Same Day          20.850203
# Name: Order Profit Per Order, dtype: float64

# %%
df[['Sales', 'Order Profit Per Order']].corr()
# Out:
#                            Sales  Order Profit Per Order
# Sales                   1.000000                0.131816
# Order Profit Per Order  0.131816                1.000000

# %%
df.groupby('Category Name')['Sales'] \
  .sum() \
  .sort_values(ascending=False) \
  .head(10)
# Out:
# Category Name
# Fishing                 6.929654e+06
# Cleats                  4.431943e+06
# Camping & Hiking        4.118426e+06
# Cardio Equipment        3.694843e+06
# Women's Apparel         3.147800e+06
# Water Sports            3.113845e+06
# Men's Footwear          2.891758e+06
# Indoor/Outdoor Games    2.888994e+06
# Shop By Sport           1.309522e+06
# Computers               6.630000e+05
# Name: Sales, dtype: float64

# %%
df.groupby('Category Name')[['Sales', 'Order Profit Per Order']].sum() \
  .sort_values('Sales', ascending=False)
# Out:
#                              Sales  Order Profit Per Order
# Category Name
# Fishing               6.929654e+06           756220.767190
# Cleats                4.431943e+06           494636.919791
# Camping & Hiking      4.118426e+06           427455.568106
# Cardio Equipment      3.694843e+06           383011.098485
# Women's Apparel       3.147800e+06           350421.029567
# Water Sports          3.113845e+06           325146.960038
# Men's Footwear        2.891758e+06           311902.820214
# Indoor/Outdoor Games  2.888994e+06           318451.430554
# Shop By Sport         1.309522e+06           129813.960315
# Computers             6.630000e+05            69656.810171
# Electronics           3.710346e+05            40891.379918
# Cameras               2.676077e+05            30289.799946
# Garden                2.577687e+05            33443.010106
# Children's Clothing   2.328292e+05            27178.099597
# Crafts                2.233563e+05            25531.170060
# ...

# %%
df.to_csv('final_supply_chain_eda_ready.csv', index=False)

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Fname', 'Customer Id', 'Customer Lname',
#        'Customer Segment', 'Customer State', 'Customer Street',
#        'Customer Zipcode', 'Department Id', 'Department Name', 'Latitude',
#        'Longitude', 'Market', 'Order City', 'Order Country',
#        'Order Customer Id', 'order date (DateOrders)', 'Order Id',
#        'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Sales',
#        'Order Item Total', 'Order Profit Per Order', 'Order Region',
#        'Order State', 'Order Status', 'Product Card Id', 'Product Category Id',
# ...

# %%
df.drop(columns=['order_date_raw', 'shipping_date_raw']).to_csv(
    'supply_chain_analytics_dataset.csv',
    index=False
)
